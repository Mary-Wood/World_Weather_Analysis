# %%
#Import Dependancies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
#Import the datetime module from the datetime library
from datetime import datetime
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = lat_lngs
#print(coordinates)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#print(cities)
# Out:
# 767

# %%
#Create empty list to hold the weather data
city_data = []
#print the beginning of the logging
print("Beginning Data Retrieval       ")
print("---------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
                
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        # If an error is experienced, skip the city.
      
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Wind Speed": city_wind,
                          "Cloudiness": city_clouds,
                          "Country": city_country})
    except:
       print("City not found. Skipping...")
       pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | vila franca do campo
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | veracruz
# Processing Record 6 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 1 | igrim
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | guerrero negro
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | saint anthony
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | zonguldak
# Processing Record 16 of Set 1 | cervo
# Processing Record 17 of Set 1 | mattru
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | visavadar
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | sorkjosen
# Processing Record 23 of Set 1 | bataipora
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | shingu
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | along
# Processing Record 29 of Set 1 | freeport
# Processing Record 30 of Set 1 | bad wildbad
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | olafsvik
# Processing Record 35 of Set 1 | rundu
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | tikaitnagar
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | sechura
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | goderich
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | kavieng
# Processing Record 47 of Set 1 | camana
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | taoudenni
# Processing Record 3 of Set 2 | solnechnyy
# Processing Record 4 of Set 2 | warwick
# Processing Record 5 of Set 2 | sisimiut
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | kharp
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | kampene
# Processing Record 10 of Set 2 | dubbo
# Processing Record 11 of Set 2 | tura
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | harqalah
# Processing Record 15 of Set 2 | dunedin
# Processing Record 16 of Set 2 | sorong
# Processing Record 17 of Set 2 | la palma
# Processing Record 18 of Set 2 | mackenzie
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | qaqortoq
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | bela vista
# Processing Record 27 of Set 2 | berdigestyakh
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | soyo
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | bitung
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | sabang
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | hagere selam
# Processing Record 37 of Set 2 | hwange
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | adrar
# Processing Record 40 of Set 2 | cam ranh
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | pechenga
# Processing Record 43 of Set 2 | abalak
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | koslan
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | mlimba
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | rantepao
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | kedarnath
# City not found. Skipping...
# Processing Record 4 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 3 | katherine
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | brenham
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | cacapava
# Processing Record 10 of Set 3 | meulaboh
# Processing Record 11 of Set 3 | luau
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | vershino-darasunskiy
# Processing Record 14 of Set 3 | tigbinan
# Processing Record 15 of Set 3 | kishi
# Processing Record 16 of Set 3 | harbour breton
# Processing Record 17 of Set 3 | nanortalik
# Processing Record 18 of Set 3 | banda aceh
# Processing Record 19 of Set 3 | caudebec-les-elbeuf
# Processing Record 20 of Set 3 | hualmay
# Processing Record 21 of Set 3 | chacabuco
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | port lincoln
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | timizart
# Processing Record 27 of Set 3 | calvia
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | cape town
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | saint-junien
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | tlahualilo
# City not found. Skipping...
# Processing Record 41 of Set 3 | saint-augustin
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | fare
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | hofn
# Processing Record 46 of Set 3 | tautira
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | bilina
# Processing Record 49 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 1 of Set 4 | sheridan
# Processing Record 2 of Set 4 | kurush
# Processing Record 3 of Set 4 | raudeberg
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | poum
# Processing Record 7 of Set 4 | naifaru
# Processing Record 8 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | little baguio
# Processing Record 10 of Set 4 | belyy yar
# Processing Record 11 of Set 4 | brae
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | hollola
# Processing Record 16 of Set 4 | sao jose da coroa grande
# Processing Record 17 of Set 4 | dwarka
# Processing Record 18 of Set 4 | kathu
# Processing Record 19 of Set 4 | agirish
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | bennettsville
# Processing Record 22 of Set 4 | manjakandriana
# Processing Record 23 of Set 4 | burnie
# Processing Record 24 of Set 4 | podor
# Processing Record 25 of Set 4 | okhotsk
# Processing Record 26 of Set 4 | iqaluit
# Processing Record 27 of Set 4 | praia da vitoria
# Processing Record 28 of Set 4 | hue
# Processing Record 29 of Set 4 | cienfuegos
# Processing Record 30 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | souris
# Processing Record 33 of Set 4 | anuchino
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | dzaoudzi
# Processing Record 36 of Set 4 | dawson creek
# Processing Record 37 of Set 4 | takoradi
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | chalons-en-champagne
# Processing Record 40 of Set 4 | hay river
# Processing Record 41 of Set 4 | akyab
# Processing Record 42 of Set 4 | parvatipuram
# Processing Record 43 of Set 4 | tharad
# Processing Record 44 of Set 4 | tecpan
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | okha
# Processing Record 47 of Set 4 | sheltozero
# Processing Record 48 of Set 4 | baruun-urt
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | xining
# Processing Record 1 of Set 5 | san isidro
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | tieli
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | lagos
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | klyuchi
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | pahrump
# Processing Record 10 of Set 5 | kidal
# Processing Record 11 of Set 5 | benghazi
# Processing Record 12 of Set 5 | diglur
# Processing Record 13 of Set 5 | rocha
# Processing Record 14 of Set 5 | qandala
# Processing Record 15 of Set 5 | youghal
# Processing Record 16 of Set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | port-gentil
# Processing Record 19 of Set 5 | porto velho
# Processing Record 20 of Set 5 | dicabisagan
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | khatanga
# Processing Record 23 of Set 5 | haines junction
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 5 | channel-port aux basques
# Processing Record 28 of Set 5 | lubango
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | guadalupe y calvo
# Processing Record 31 of Set 5 | nioro
# Processing Record 32 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 5 | ponta do sol
# Processing Record 34 of Set 5 | nossa senhora da gloria
# Processing Record 35 of Set 5 | van
# Processing Record 36 of Set 5 | chernyshevskiy
# Processing Record 37 of Set 5 | narsaq
# Processing Record 38 of Set 5 | severo-kurilsk
# Processing Record 39 of Set 5 | manadhoo
# Processing Record 40 of Set 5 | novoagansk
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | aloleng
# Processing Record 43 of Set 5 | paujiles
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | mamlyutka
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | mangrol
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | grand-lahou
# Processing Record 50 of Set 5 | cayenne
# Processing Record 1 of Set 6 | murray bridge
# Processing Record 2 of Set 6 | srednekolymsk
# Processing Record 3 of Set 6 | ocotepec
# Processing Record 4 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 6 | rudbar
# Processing Record 6 of Set 6 | iquitos
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | jurm
# Processing Record 9 of Set 6 | pierre
# Processing Record 10 of Set 6 | sioux lookout
# Processing Record 11 of Set 6 | pontes e lacerda
# Processing Record 12 of Set 6 | cabedelo
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | ambon
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | tromso
# Processing Record 17 of Set 6 | sobolevo
# Processing Record 18 of Set 6 | vanimo
# Processing Record 19 of Set 6 | xinmin
# Processing Record 20 of Set 6 | ornskoldsvik
# Processing Record 21 of Set 6 | olinda
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | zacapoaxtla
# Processing Record 24 of Set 6 | marzuq
# Processing Record 25 of Set 6 | eufaula
# Processing Record 26 of Set 6 | north myrtle beach
# Processing Record 27 of Set 6 | clinton
# Processing Record 28 of Set 6 | aykhal
# Processing Record 29 of Set 6 | mayo
# Processing Record 30 of Set 6 | comodoro rivadavia
# Processing Record 31 of Set 6 | vostok
# Processing Record 32 of Set 6 | maryville
# Processing Record 33 of Set 6 | duiwelskloof
# Processing Record 34 of Set 6 | vardo
# Processing Record 35 of Set 6 | yelets
# Processing Record 36 of Set 6 | aripuana
# Processing Record 37 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 6 | gannan
# Processing Record 39 of Set 6 | camacha
# Processing Record 40 of Set 6 | sola
# Processing Record 41 of Set 6 | ust-omchug
# Processing Record 42 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 6 | mana
# Processing Record 44 of Set 6 | port hardy
# Processing Record 45 of Set 6 | kodiak
# Processing Record 46 of Set 6 | porto belo
# Processing Record 47 of Set 6 | christchurch
# Processing Record 48 of Set 6 | bambous virieux
# Processing Record 49 of Set 6 | kampong cham
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | ucluelet
# Processing Record 3 of Set 7 | yatou
# Processing Record 4 of Set 7 | birin
# Processing Record 5 of Set 7 | burns lake
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | beyneu
# Processing Record 8 of Set 7 | thompson
# Processing Record 9 of Set 7 | taltal
# Processing Record 10 of Set 7 | los llanos de aridane
# Processing Record 11 of Set 7 | atbasar
# Processing Record 12 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 7 | pevek
# Processing Record 14 of Set 7 | san quintin
# Processing Record 15 of Set 7 | seydisehir
# Processing Record 16 of Set 7 | krasnoselkup
# Processing Record 17 of Set 7 | maceio
# Processing Record 18 of Set 7 | tall kayf
# Processing Record 19 of Set 7 | ternate
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | vajszlo
# Processing Record 22 of Set 7 | dunmore east
# Processing Record 23 of Set 7 | sehithwa
# Processing Record 24 of Set 7 | dharmanagar
# Processing Record 25 of Set 7 | panuco
# Processing Record 26 of Set 7 | namibe
# Processing Record 27 of Set 7 | perelyub
# Processing Record 28 of Set 7 | dakar
# Processing Record 29 of Set 7 | aksarka
# Processing Record 30 of Set 7 | duobao
# Processing Record 31 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 7 | yaan
# Processing Record 33 of Set 7 | leningradskiy
# Processing Record 34 of Set 7 | nelson bay
# Processing Record 35 of Set 7 | richards bay
# Processing Record 36 of Set 7 | buala
# Processing Record 37 of Set 7 | altonia
# City not found. Skipping...
# Processing Record 38 of Set 7 | paramonga
# Processing Record 39 of Set 7 | alugan
# Processing Record 40 of Set 7 | burica
# City not found. Skipping...
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | salinas
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | kirovsk
# Processing Record 45 of Set 7 | kalawit
# Processing Record 46 of Set 7 | niamey
# Processing Record 47 of Set 7 | tawzar
# City not found. Skipping...
# Processing Record 48 of Set 7 | ishikari
# Processing Record 49 of Set 7 | damietta
# Processing Record 50 of Set 7 | inta
# Processing Record 1 of Set 8 | pouebo
# Processing Record 2 of Set 8 | nelspruit
# Processing Record 3 of Set 8 | nizhniy tsasuchey
# Processing Record 4 of Set 8 | dourados
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | quelimane
# Processing Record 8 of Set 8 | duvan
# Processing Record 9 of Set 8 | santa isabel do rio negro
# Processing Record 10 of Set 8 | balkhash
# Processing Record 11 of Set 8 | bengkulu
# Processing Record 12 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 8 | amapa
# Processing Record 14 of Set 8 | zhigansk
# Processing Record 15 of Set 8 | kupang
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | batagay-alyta
# Processing Record 19 of Set 8 | griffith
# Processing Record 20 of Set 8 | chipinge
# Processing Record 21 of Set 8 | kutum
# Processing Record 22 of Set 8 | hudson bay
# Processing Record 23 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | chibombo
# Processing Record 26 of Set 8 | troitskiy
# Processing Record 27 of Set 8 | verkhoyansk
# Processing Record 28 of Set 8 | frontera
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | nouadhibou
# Processing Record 32 of Set 8 | dauriya
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | springdale
# Processing Record 35 of Set 8 | tuatapere
# Processing Record 36 of Set 8 | yerbogachen
# Processing Record 37 of Set 8 | viedma
# Processing Record 38 of Set 8 | pokhvistnevo
# Processing Record 39 of Set 8 | sao filipe
# Processing Record 40 of Set 8 | high level
# Processing Record 41 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 8 | tacoronte
# Processing Record 43 of Set 8 | kuching
# Processing Record 44 of Set 8 | ashland
# Processing Record 45 of Set 8 | kieta
# Processing Record 46 of Set 8 | khanpur
# Processing Record 47 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 8 | zhangye
# Processing Record 49 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 8 | snezhnogorsk
# Processing Record 1 of Set 9 | prince rupert
# Processing Record 2 of Set 9 | koutiala
# Processing Record 3 of Set 9 | yangjiang
# Processing Record 4 of Set 9 | bintulu
# Processing Record 5 of Set 9 | sumenep
# Processing Record 6 of Set 9 | powell river
# Processing Record 7 of Set 9 | xai-xai
# Processing Record 8 of Set 9 | gashua
# Processing Record 9 of Set 9 | aswan
# Processing Record 10 of Set 9 | gat
# Processing Record 11 of Set 9 | tual
# Processing Record 12 of Set 9 | kastamonu
# Processing Record 13 of Set 9 | riyadh
# Processing Record 14 of Set 9 | fortuna
# Processing Record 15 of Set 9 | cuiluan
# Processing Record 16 of Set 9 | buckeye
# Processing Record 17 of Set 9 | sabibah
# City not found. Skipping...
# Processing Record 18 of Set 9 | ancud
# Processing Record 19 of Set 9 | fairbanks
# Processing Record 20 of Set 9 | alice springs
# Processing Record 21 of Set 9 | borogontsy
# Processing Record 22 of Set 9 | mugur-aksy
# Processing Record 23 of Set 9 | saint-denis
# Processing Record 24 of Set 9 | hillsborough
# Processing Record 25 of Set 9 | kristiinankaupunki
# Processing Record 26 of Set 9 | mount darwin
# Processing Record 27 of Set 9 | saint-joseph
# Processing Record 28 of Set 9 | pelym
# Processing Record 29 of Set 9 | kalundborg
# Processing Record 30 of Set 9 | goure
# Processing Record 31 of Set 9 | gazojak
# Processing Record 32 of Set 9 | flinders
# Processing Record 33 of Set 9 | mount isa
# Processing Record 34 of Set 9 | la uribe
# City not found. Skipping...
# Processing Record 35 of Set 9 | umm kaddadah
# Processing Record 36 of Set 9 | itanagar
# Processing Record 37 of Set 9 | wenatchee
# Processing Record 38 of Set 9 | bosaso
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | svetlaya
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | mantua
# Processing Record 43 of Set 9 | constantine
# Processing Record 44 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | rawson
# Processing Record 47 of Set 9 | fukue
# Processing Record 48 of Set 9 | qui nhon
# Processing Record 49 of Set 9 | ilo
# Processing Record 50 of Set 9 | lata
# Processing Record 1 of Set 10 | codrington
# Processing Record 2 of Set 10 | champerico
# Processing Record 3 of Set 10 | yanam
# Processing Record 4 of Set 10 | matay
# Processing Record 5 of Set 10 | san juan
# Processing Record 6 of Set 10 | abu zabad
# Processing Record 7 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 8 of Set 10 | villaviciosa
# Processing Record 9 of Set 10 | comarapa
# Processing Record 10 of Set 10 | college
# Processing Record 11 of Set 10 | santa cruz
# Processing Record 12 of Set 10 | puerto del rosario
# Processing Record 13 of Set 10 | chumikan
# Processing Record 14 of Set 10 | talara
# Processing Record 15 of Set 10 | vestmannaeyjar
# Processing Record 16 of Set 10 | yulara
# Processing Record 17 of Set 10 | abnub
# Processing Record 18 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | terrasini
# Processing Record 21 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 10 | balabac
# Processing Record 23 of Set 10 | tomatlan
# Processing Record 24 of Set 10 | ortega
# Processing Record 25 of Set 10 | corrente
# Processing Record 26 of Set 10 | podosinovets
# Processing Record 27 of Set 10 | guane
# Processing Record 28 of Set 10 | pimentel
# Processing Record 29 of Set 10 | kulhudhuffushi
# Processing Record 30 of Set 10 | inverell
# Processing Record 31 of Set 10 | saint-pierre
# Processing Record 32 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 10 | mpulungu
# Processing Record 34 of Set 10 | gizo
# Processing Record 35 of Set 10 | peleduy
# Processing Record 36 of Set 10 | shimoda
# Processing Record 37 of Set 10 | abha
# Processing Record 38 of Set 10 | kjopsvik
# Processing Record 39 of Set 10 | hami
# Processing Record 40 of Set 10 | karasjok
# Processing Record 41 of Set 10 | sarti
# Processing Record 42 of Set 10 | mnogovershinnyy
# Processing Record 43 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | north charleston
# Processing Record 45 of Set 10 | calama
# Processing Record 46 of Set 10 | sirjan
# Processing Record 47 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 10 | mogadishu
# Processing Record 49 of Set 10 | kingsland
# Processing Record 50 of Set 10 | kaseda
# Processing Record 1 of Set 11 | lasa
# Processing Record 2 of Set 11 | waipawa
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | abilene
# Processing Record 5 of Set 11 | kaili
# Processing Record 6 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 7 of Set 11 | krasnogorsk
# Processing Record 8 of Set 11 | horconcitos
# Processing Record 9 of Set 11 | hailar
# Processing Record 10 of Set 11 | khandyga
# Processing Record 11 of Set 11 | jumla
# Processing Record 12 of Set 11 | zeya
# Processing Record 13 of Set 11 | san pedro
# Processing Record 14 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 11 | bulgan
# Processing Record 16 of Set 11 | vimperk
# Processing Record 17 of Set 11 | puerto escondido
# Processing Record 18 of Set 11 | lianran
# Processing Record 19 of Set 11 | los lunas
# Processing Record 20 of Set 11 | zharkent
# Processing Record 21 of Set 11 | vila velha
# Processing Record 22 of Set 11 | paragould
# Processing Record 23 of Set 11 | san-pedro
# Processing Record 24 of Set 11 | asau
# Processing Record 25 of Set 11 | oriximina
# Processing Record 26 of Set 11 | mizdah
# Processing Record 27 of Set 11 | koumac
# Processing Record 28 of Set 11 | yuryev-polskiy
# Processing Record 29 of Set 11 | townsville
# Processing Record 30 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 11 | ouagadougou
# Processing Record 32 of Set 11 | constitucion
# Processing Record 33 of Set 11 | havoysund
# Processing Record 34 of Set 11 | cascais
# Processing Record 35 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 36 of Set 11 | gadung
# Processing Record 37 of Set 11 | jacareacanga
# Processing Record 38 of Set 11 | hirado
# Processing Record 39 of Set 11 | hovd
# Processing Record 40 of Set 11 | broome
# Processing Record 41 of Set 11 | qaanaaq
# Processing Record 42 of Set 11 | pacific grove
# Processing Record 43 of Set 11 | rivadavia
# Processing Record 44 of Set 11 | anadyr
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | nogliki
# Processing Record 47 of Set 11 | mackay
# Processing Record 48 of Set 11 | henties bay
# Processing Record 49 of Set 11 | samarai
# Processing Record 50 of Set 11 | erechim
# Processing Record 1 of Set 12 | monki
# Processing Record 2 of Set 12 | acworth
# Processing Record 3 of Set 12 | iwaki
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | vallenar
# Processing Record 6 of Set 12 | maksatikha
# Processing Record 7 of Set 12 | alofi
# Processing Record 8 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 9 of Set 12 | guayaramerin
# Processing Record 10 of Set 12 | soto la marina
# Processing Record 11 of Set 12 | the valley
# Processing Record 12 of Set 12 | fuyu
# Processing Record 13 of Set 12 | gari
# Processing Record 14 of Set 12 | ambulu
# Processing Record 15 of Set 12 | abulug
# Processing Record 16 of Set 12 | kirakira
# Processing Record 17 of Set 12 | mangai
# Processing Record 18 of Set 12 | nantucket
# Processing Record 19 of Set 12 | whitehorse
# Processing Record 20 of Set 12 | terney
# Processing Record 21 of Set 12 | salihli
# Processing Record 22 of Set 12 | dingle
# Processing Record 23 of Set 12 | valleyview
# Processing Record 24 of Set 12 | tuy hoa
# Processing Record 25 of Set 12 | laela
# Processing Record 26 of Set 12 | doctor juan manuel frutos
# Processing Record 27 of Set 12 | grindavik
# Processing Record 28 of Set 12 | ulladulla
# Processing Record 29 of Set 12 | egvekinot
# Processing Record 30 of Set 12 | troitsko-pechorsk
# Processing Record 31 of Set 12 | slave lake
# Processing Record 32 of Set 12 | plainview
# Processing Record 33 of Set 12 | veraval
# Processing Record 34 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 12 | shambu
# Processing Record 36 of Set 12 | tupik
# Processing Record 37 of Set 12 | axim
# Processing Record 38 of Set 12 | berlevag
# Processing Record 39 of Set 12 | cap malheureux
# Processing Record 40 of Set 12 | villamartin
# Processing Record 41 of Set 12 | seattle
# Processing Record 42 of Set 12 | hurricane
# Processing Record 43 of Set 12 | puerto carreno
# Processing Record 44 of Set 12 | luis correia
# Processing Record 45 of Set 12 | alagoinhas
# Processing Record 46 of Set 12 | marsh harbour
# Processing Record 47 of Set 12 | katsuura
# Processing Record 48 of Set 12 | nieves
# Processing Record 49 of Set 12 | padang
# Processing Record 50 of Set 12 | jimo
# Processing Record 1 of Set 13 | kendari
# Processing Record 2 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 3 of Set 13 | stranda
# Processing Record 4 of Set 13 | teahupoo
# Processing Record 5 of Set 13 | khash
# Processing Record 6 of Set 13 | ovalle
# Processing Record 7 of Set 13 | alta floresta
# Processing Record 8 of Set 13 | honningsvag
# Processing Record 9 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 10 of Set 13 | asfi
# Processing Record 11 of Set 13 | pathein
# Processing Record 12 of Set 13 | coahuayana
# Processing Record 13 of Set 13 | santa rosalia
# Processing Record 14 of Set 13 | siparia
# Processing Record 15 of Set 13 | hacari
# Processing Record 16 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 13 | del rio
# Processing Record 18 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 20 of Set 13 | kudahuvadhoo
# Processing Record 21 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 22 of Set 13 | dahra
# Processing Record 23 of Set 13 | namatanai
# Processing Record 24 of Set 13 | abay
# Processing Record 25 of Set 13 | arroio grande
# Processing Record 26 of Set 13 | el balyana
# City not found. Skipping...
# Processing Record 27 of Set 13 | teruel
# Processing Record 28 of Set 13 | turkistan
# Processing Record 29 of Set 13 | kuytun
# Processing Record 30 of Set 13 | sloboda
# Processing Record 31 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 13 | acarau
# Processing Record 33 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 34 of Set 13 | saldanha
# Processing Record 35 of Set 13 | lukulu
# Processing Record 36 of Set 13 | mandal
# Processing Record 37 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 13 | pietersburg
# Processing Record 39 of Set 13 | karratha
# Processing Record 40 of Set 13 | buin
# Processing Record 41 of Set 13 | saratoga springs
# Processing Record 42 of Set 13 | nazca
# Processing Record 43 of Set 13 | kraskino
# Processing Record 44 of Set 13 | flin flon
# Processing Record 45 of Set 13 | energetik
# Processing Record 46 of Set 13 | prince george
# Processing Record 47 of Set 13 | mets masrik
# Processing Record 48 of Set 13 | vestmanna
# Processing Record 49 of Set 13 | black river
# Processing Record 50 of Set 13 | ferrol
# Processing Record 1 of Set 14 | marsa matruh
# Processing Record 2 of Set 14 | matata
# Processing Record 3 of Set 14 | xingyi
# Processing Record 4 of Set 14 | san ignacio
# Processing Record 5 of Set 14 | maniitsoq
# Processing Record 6 of Set 14 | jeremoabo
# Processing Record 7 of Set 14 | palmer
# Processing Record 8 of Set 14 | san vicente
# Processing Record 9 of Set 14 | opuwo
# Processing Record 10 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 11 of Set 14 | linkou
# Processing Record 12 of Set 14 | hope
# Processing Record 13 of Set 14 | tessalit
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | pakokku
# Processing Record 16 of Set 14 | ewa beach
# Processing Record 17 of Set 14 | carballo
# Processing Record 18 of Set 14 | north vernon
# Processing Record 19 of Set 14 | camacupa
# Processing Record 20 of Set 14 | ocos
# Processing Record 21 of Set 14 | plouzane
# Processing Record 22 of Set 14 | saint-gabriel
# Processing Record 23 of Set 14 | novyy urgal
# Processing Record 24 of Set 14 | shieli
# Processing Record 25 of Set 14 | kostomuksha
# Processing Record 26 of Set 14 | catumbela
# Processing Record 27 of Set 14 | tutoia
# Processing Record 28 of Set 14 | plettenberg bay
# Processing Record 29 of Set 14 | wajir
# Processing Record 30 of Set 14 | sistranda
# Processing Record 31 of Set 14 | nyurba
# Processing Record 32 of Set 14 | callaway
# Processing Record 33 of Set 14 | pato branco
# Processing Record 34 of Set 14 | manggar
# Processing Record 35 of Set 14 | taiping
# Processing Record 36 of Set 14 | poroshkovo
# Processing Record 37 of Set 14 | gemena
# Processing Record 38 of Set 14 | omboue
# Processing Record 39 of Set 14 | ronne
# Processing Record 40 of Set 14 | isangel
# Processing Record 41 of Set 14 | lamar
# Processing Record 42 of Set 14 | camocim
# Processing Record 43 of Set 14 | bara
# Processing Record 44 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 14 | irtyshskiy
# Processing Record 46 of Set 14 | dauphin
# Processing Record 47 of Set 14 | el salto
# Processing Record 48 of Set 14 | salina
# Processing Record 49 of Set 14 | san jose
# Processing Record 50 of Set 14 | mucuri
# Processing Record 1 of Set 15 | vaitape
# Processing Record 2 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 15 | salalah
# Processing Record 4 of Set 15 | konevo
# Processing Record 5 of Set 15 | marinette
# Processing Record 6 of Set 15 | naantali
# Processing Record 7 of Set 15 | ewo
# Processing Record 8 of Set 15 | ville-marie
# Processing Record 9 of Set 15 | volsk
# Processing Record 10 of Set 15 | kulu
# Processing Record 11 of Set 15 | ballina
# Processing Record 12 of Set 15 | parras
# City not found. Skipping...
# Processing Record 13 of Set 15 | tibati
# Processing Record 14 of Set 15 | sunrise manor
# Processing Record 15 of Set 15 | hambantota
# Processing Record 16 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 15 | anzio
# Processing Record 18 of Set 15 | atlantic beach
# Processing Record 19 of Set 15 | moose factory
# Processing Record 20 of Set 15 | tapa
# Processing Record 21 of Set 15 | dzidzantun
# Processing Record 22 of Set 15 | stolac
# Processing Record 23 of Set 15 | te anau
# Processing Record 24 of Set 15 | kokopo
# Processing Record 25 of Set 15 | sao bento do sul
# Processing Record 26 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 27 of Set 15 | mareeba
# Processing Record 28 of Set 15 | gerardmer
# Processing Record 29 of Set 15 | ratnagiri
# Processing Record 30 of Set 15 | san angelo
# Processing Record 31 of Set 15 | lagunas
# Processing Record 32 of Set 15 | sanchez
# Processing Record 33 of Set 15 | mahajanga
# Processing Record 34 of Set 15 | corinto
# Processing Record 35 of Set 15 | san rafael
# Processing Record 36 of Set 15 | ouargaye
# Processing Record 37 of Set 15 | banga
# Processing Record 38 of Set 15 | llanes
# Processing Record 39 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 15 | kiruna
# Processing Record 41 of Set 15 | roald
# Processing Record 42 of Set 15 | hit
# Processing Record 43 of Set 15 | turukhansk
# Processing Record 44 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 15 | pangnirtung
# Processing Record 46 of Set 15 | sept-iles
# Processing Record 47 of Set 15 | morgan city
# Processing Record 48 of Set 15 | ponta delgada
# Processing Record 49 of Set 15 | ola
# Processing Record 50 of Set 15 | saiki
# Processing Record 1 of Set 16 | zhangjiakou
# Processing Record 2 of Set 16 | el copey
# Processing Record 3 of Set 16 | mindelo
# Processing Record 4 of Set 16 | georgiyevskoye
# Processing Record 5 of Set 16 | doctor arroyo
# Processing Record 6 of Set 16 | kingisepp
# Processing Record 7 of Set 16 | port hedland
# Processing Record 8 of Set 16 | patiya
# Processing Record 9 of Set 16 | huntly
# Processing Record 10 of Set 16 | mersing
# Processing Record 11 of Set 16 | pilar
# Processing Record 12 of Set 16 | guhagar
# Processing Record 13 of Set 16 | waw
# Processing Record 14 of Set 16 | medvezhyegorsk
# Processing Record 15 of Set 16 | mirnyy
# Processing Record 16 of Set 16 | lanigan
# Processing Record 17 of Set 16 | liverpool
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a pandas df
city_data_df = []
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ]
city_data_df = city_data_df[new_column_order]

#Create an output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export data to CSV
city_data_df.to_csv(output_data_file, index_label = "City ID")

# %%
city_data_df.head()
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Yellowknife      CA  62.4560 -114.3525     40.28        93
# 1              Hermanus      ZA -34.4187   19.2345     63.81        78
# 2  Vila Franca Do Campo      PT  37.7167  -25.4333     73.81        67
# 3          Punta Arenas      CL -53.1500  -70.9167     50.11        46
# 4              Veracruz      MX  19.3333  -96.6667     68.90        82
#
#    Cloudiness  Wind Speed Current Description
# 0          20        4.61          few clouds
# 1          87       14.18     overcast clouds
# 2          13        3.09          few clouds
# 3          20       40.29          few clouds
# 4          99        2.26     overcast clouds
